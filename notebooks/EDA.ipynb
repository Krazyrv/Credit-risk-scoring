# %% [markdown]
# # 1. Setup and Data Loading

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

print('✅ Libraries loaded successfully')

# %%
try:
    df = pd.read_csv("../data/01-raw/applications.csv")
    print('✅ Data loaded successfully!\nWith shape:', df.shape)
except FileNotFoundError:
    print('❌ Data file not found. Please check the file path.')
except Exception as e:
    print(f'❌ Error loading data: {e}')

df.head()
# Out:
# ✅ Data loaded successfully!
# With shape: (50000, 13)
#   application_id  age  income  employment_length  loan_amount  \
# 0     APP0000001   43   53980                 10        12112
# 1     APP0000002   21   52586                  2        25335
# 2     APP0000003   32  112395                  5        44713
# 3     APP0000004   57   77387                 34        40232
# 4     APP0000005   43   83581                 22        22466
#
#          loan_purpose  debt_to_income  credit_history_length  \
# 0      major_purchase           0.131                      7
# 1            vacation           0.142                      0
# 2             medical           0.202                      9
# 3  debt_consolidation           0.201                     34
# 4            vacation           0.257                     13
#
#    num_credit_lines  utilization_rate home_ownership  num_delinquencies  \
# 0                 3              22.2           RENT                  0
# ...

# %%
# try:
#     df_2023 = pd.read_csv("../data/01-raw/data_2023.csv")
#     print('✅ Data loaded successfully!\nWith shape:', df_2023.shape)
# except FileNotFoundError:
#     print('❌ Data file not found. Please check the file path.')
# except Exception as e:
#     print(f'❌ Error loading data: {e}')

# df_2023.head().T

# %% [markdown]
# # 2. Data Overview

# %%
# Basic info
print('📊 Dataset Summary')
print('=' * 50)
print(f"Total applicants: {len(df):,}")
print(f"Features: {len(df.columns) - 1}")
print(f"\nDefault Distribution:")
print(df['default'].value_counts(normalize=True).round(3) * 100)
# Out:
# 📊 Dataset Summary
# ...
# Total applicants: 50,000
# Features: 12
#
# Default Distribution:
# default
# 0    81.2
# 1    18.8
# Name: proportion, dtype: float64

# %%
print("Basic dataset info displayed:")
info_df = pd.DataFrame({
    'Column': df.columns,
    'Data Type': df.dtypes,
    'Non-Null Count': df.notnull().sum(),
    'Unique Values': df.nunique(),
    'Missing Values': df.isnull().sum(),
    'Missing %': (df.isnull().mean() * 100).round(2)
})
info_df
# Out:
# Basic dataset info displayed:
#                                       Column Data Type  Non-Null Count  \
# application_id                application_id    object           50000
# age                                      age     int64           50000
# income                                income     int64           50000
# employment_length          employment_length     int64           50000
# loan_amount                      loan_amount     int64           50000
# loan_purpose                    loan_purpose    object           50000
# debt_to_income                debt_to_income   float64           50000
# credit_history_length  credit_history_length     int64           50000
# num_credit_lines            num_credit_lines     int64           50000
# utilization_rate            utilization_rate   float64           50000
# home_ownership                home_ownership    object           50000
# num_delinquencies          num_delinquencies     int64           50000
# ...

# %%
fig, ax = plt.subplots(figsize=(15, 6))
